# %% [markdown]
# <a href="https://colab.research.google.com/github/elaineandus/anduselaine/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing the Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f3a00d47-12bb-40fa-8e07-bb360ab6693e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f3a00d47-12bb-40fa-8e07-bb360ab6693e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving movie_data.csv to movie_data.csv

# %%
andusestrella = pd.read_csv('movie_data.csv')

# %%
#Head of the dataset
andusestrella.head()
# Out:
#    Rank                    Title  ... Revenue (Millions) Metascore
# 0     1  Guardians of the Galaxy  ...             333.13      76.0
# 1     2               Prometheus  ...             126.46      65.0
# 2     3                    Split  ...             138.12      62.0
# 3     4                     Sing  ...             270.32      59.0
# 4     5            Suicide Squad  ...             325.02      40.0
#
# [5 rows x 12 columns]

# %%
#Dimension of the Dataset
andusestrella.shape
# Out:
# (1000, 12)

# %%
#Info the dataset
andusestrella.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
#Just an initial statistic
andusestrella.describe()
# Out:
#               Rank         Year  ...  Revenue (Millions)   Metascore
# count  1000.000000  1000.000000  ...          872.000000  936.000000
# mean    500.500000  2012.783000  ...           82.956376   58.985043
# std     288.819436     3.205962  ...          103.253540   17.194757
# min       1.000000  2006.000000  ...            0.000000   11.000000
# 25%     250.750000  2010.000000  ...           13.270000   47.000000
# 50%     500.500000  2014.000000  ...           47.985000   59.500000
# 75%     750.250000  2016.000000  ...          113.715000   72.000000
# max    1000.000000  2016.000000  ...          936.630000  100.000000
#
# [8 rows x 7 columns]

# %%
#Just trying to plot the above seen initial stats
andusestrella.describe().plot(kind='area',fontsize=10,figsize=(20,8),colormap='rainbow')
plt.title("Initial Stats for the Dataset",fontweight='bold')
plt.ylabel("Value")
plt.show()

# %%
# Let us take a look at the genres of the movies
f, ax = plt.subplots(figsize=(7, 10))
sns.countplot(y = "Genre", data = andusestrella)

# %%
# Let us take a look at the votes of the movies
f, ax = plt.subplots(figsize=(7, 10))
sns.countplot(y = "Votes", data = andusestrella)

# %%
# Let us take a look at the titles of the movies
f, ax = plt.subplots(figsize=(7, 10))
sns.countplot(y = "Title", data = andusestrella)

# %%
# Let us take a look at the actors of the movies
f, ax = plt.subplots(figsize=(7, 10))
sns.countplot(y = "Actors", data = andusestrella)

# %%
# Let us now check for missing values
andusestrella.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
# Checking for outliers
sns.boxplot(x ='Title',y = 'Rating',data = andusestrella,palette ='rainbow')

# %%
# Checking for outliers
sns.boxplot(x ='Genre',y = 'Rating',data = andusestrella,palette ='rainbow')

# %%
# Checking for outliers
sns.boxplot(x ='Actors',y = 'Rating',data = andusestrella,palette ='rainbow')

# %%
# Replace using median 
median = andusestrella['Rating'].median()
andusestrella['Rating'].fillna(median, inplace=True)

# %%
# Top 10 movies in the genre: 'Comedy'
top_drama = andusestrella[andusestrella['Genre'] == 'Comedy'].sort_values(by = 'Rating',ascending = False)
#Top 10 movies in comedy
top_drama.head(10)
# Out:
#      Rank                   Title  ... Revenue (Millions) Metascore
# 255   256            The Hangover  ...             277.31      73.0
# 148   149                Superbad  ...             121.46      76.0
# 278   279  Everybody Wants Some!!  ...               3.37      83.0
# 360   361           Step Brothers  ...             100.47      51.0
# 25     26         Paris pieds nus  ...                NaN       NaN
# 994   995               Project X  ...              54.72      48.0
# 639   640        American Reunion  ...              56.72      49.0
# 716   717               Entourage  ...              32.36      38.0
# 631   632           The Interview  ...               6.11      52.0
# 678   679                The DUFF  ...              34.02      56.0
#
# [10 rows x 12 columns]

# %%
# Let us take a look at the highest rated on movies
andusestrella.sort_values(by = "Rating", ascending = False).head(20)
# Out:
#      Rank                  Title  ... Revenue (Millions) Metascore
# 54     55        The Dark Knight  ...             533.32      82.0
# 80     81              Inception  ...             292.57      74.0
# 117   118                 Dangal  ...              11.15       NaN
# 36     37           Interstellar  ...             187.99      74.0
# 96     97          Kimi no na wa  ...               4.68      79.0
# 249   250       The Intouchables  ...              13.18      57.0
# 133   134               Whiplash  ...              13.09      88.0
# 64     65           The Prestige  ...              53.08      66.0
# 99    100           The Departed  ...             132.37      85.0
# 991   992       Taare Zameen Par  ...               1.20      42.0
# 124   125  The Dark Knight Rises  ...             448.13      78.0
# 476   477    The Lives of Others  ...              11.28      89.0
# 634   635                 WALL·E  ...             223.81       NaN
# ...

# %%
# Let us now take a look at the worst rated on movies
andusestrella.sort_values(by = "Rating", ascending = True).head(20)
# Out:
#      Rank                                 Title  ... Revenue (Millions) Metascore
# 829   830                        Disaster Movie  ...              14.17      15.0
# 42     43               Don't Fuck in the Woods  ...                NaN       NaN
# 871   872                  Dragonball Evolution  ...               9.35      45.0
# 647   648                              Tall Men  ...                NaN      57.0
# 968   969                               Wrecker  ...                NaN      37.0
# 890   891                            The Intent  ...                NaN      59.0
# 49     50                         The Last Face  ...                NaN      16.0
# 269   270                               Satanic  ...                NaN       NaN
# 525   526                   Birth of the Dragon  ...              93.05      61.0
# 401   402                        The Black Room  ...                NaN      71.0
# ...
